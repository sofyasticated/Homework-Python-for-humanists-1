# %% [markdown]
# # ДЗ3 (Оцениваемое)
# ## Задание 1
# Скачайте текст ["Литературных анекдотов"](https://github.com/ancatmara/python-for-dh/blob/master/Classes/9-10/literary_anecdotes.txt). Напишите функцию, которая будет читать файл, лемматизировать текст с помощью pymystem3 и записывать результат в новый файл. У функции должно бы два аргумента: путь к исходному файлу и путь к файлу с лемматизированным текстом. Вызов функции тоже должен быть прописан в решении.

# %%
def func (p):
    import os
    os.chdir (r'D:\literature')
    with open('literary_memes.txt','r',encoding='utf-8') as f:
        text = f.read()
        words = [word.strip("""!?.«»():"";,—-""") for word in text.split()]
        p = ' ' .join(words)
        from pymystem3 import Mystem 
        m = Mystem()
        global lemmas
        lemmas = m.lemmatize(p)
        s = str() 
        with open('memes_2.txt','w',encoding='utf-8') as h:
            for l in lemmas:
                h.write(l+s)
                with open ('memes_2.txt','r',encoding='utf-8') as q:
                    g = q.read()
    return (p)

# %% [markdown]
# ## Задание 2
# Очистите лемматизированный текст от стоп-слов и посчитайте ipm для оставшихся. Выведите 20 самых частотных по этому параметру слов.

# %%
with open('rus_stopwords.txt','r',encoding='utf-8') as n:
        m = n.read()
        q = m.split()
        top = []
        for i in lemmas:
            if i not in q:
                top.append(i)
                top_2=''.join(top)
from collections import Counter
counts = Counter(top_2.split())
mnogo = len(counts)
spisok = []
for s in counts.items():
    spisok.append((s[0], s[1] / mnogo * 1000000))
sorted_spisok = sorted(spisok, key=lambda x: x[1], reverse=True)
print(sorted_spisok[:20])
# Out:
# [('пушкин', 58378.37837837838), ('толстой', 34594.59459459459), ('гоголь', 33513.51351351351), ('однажды', 31351.35135135135), ('лев', 27027.02702702703), ('любить', 21621.621621621623), ('достоевский', 20540.54054054054), ('тургенев', 16216.216216216217), ('ребенок', 15135.135135135135), ('царствие', 14054.054054054055), ('окно', 12972.972972972972), ('бульвар', 12972.972972972972), ('идти', 12972.972972972972), ('лермонтов', 12972.972972972972), ('приходить', 11891.891891891892), ('тверской', 11891.891891891892), ('федор', 11891.891891891892), ('михайлович', 11891.891891891892), ('герцен', 10810.810810810812), ('небесный', 10810.810810810812)]

# %% [markdown]
# ## Задание 3
# Сделайте полный морфологический разбор исходного текста. Напишите регулярное выражение, которое будет извлекать из тега только часть речи. Пройдитесь циклом по списку с разборами, который выдал pymystem3, извлекая из каждого разбора форму слова и его часть речи и записывая их в новый словарь (форма -- ключ, часть речи -- значение). Посчитайте абсолютную частоту для всех частей речи, а затем относительнную частоту (абсолютная частота / длина текста в словах).

# %%
import re
def get(s):
    pattern = r'A|ADV|ADVPRO|ANUM|APRO|COM|CONJ|INTJ|NUM|PART|PR|S|SPRO|V'
    return re.match(pattern, s).group(0)
m = Mystem()
kuzdra = m.analyze(p2)
parts = []
for word in kuzdra:
    try:
        parts.append(get(word['analysis'][0]['gr']))
    except (KeyError, IndexError) as e:  
        pass
print(parts)
# Out:
m = Mystem()
kuzdra = m.analyze(p2)
dictionary = {}
for word in kuzdra:
    try:
        dictionary[word['text']]= get(word['analysis'][0]['gr'])
    except (KeyError, IndexError) as e:  
        pass
print(dictionary)
# Out:
# {'У': 'PR', 'Вяземского': 'S', 'была': 'V', 'квартира': 'S', 'окнами': 'S', 'на': 'PR', 'Тверской': 'A', 'бульвар': 'S', 'Пуш': 'S', 'кин': 'S', 'очень': 'A', 'любил': 'V', 'ходить': 'V', 'к': 'PR', 'нему': 'S', 'в': 'PR', 'гости': 'S', 'Придет': 'V', 'и': 'CONJ', 'сразу': 'A', 'прыг': 'A', 'подоконник': 'S', 'свесится': 'V', 'из': 'PR', 'окна': 'S', 'смотрит': 'V', 'Чай': 'S', 'ему': 'S', 'тоже': 'PART', 'туда': 'A', 'окно': 'S', 'подавали': 'V', 'Иной': 'A', 'раз': 'S', 'там': 'A', 'заночует': 'V', 'Ему': 'S', 'даже': 'PART', 'матрац': 'S', 'купили': 'V', 'специальный': 'A', 'только': 'PART', 'он': 'S', 'его': 'S', 'не': 'PART', 'признавал': 'V', 'К': 'PR', 'чему': 'S', 'говорит': 'V', 'такие': 'A', 'роскоши': 'S', 'И': 'CONJ', 'спихнет': 'V', 'с': 'PR', 'подоконника': 'S', 'А': 'CONJ', 'потом': 'A', 'всю': 'A', 'ночь': 'S', 'вертится': 'V', 'спать': 'V', 'дает': 'V', 'Гоголь': 'S', 'переоделся': 'V', 'Пушкиным': 'S', 'пришел': 'V', 'Пушкину': 'S', 'позвонил': 'V', 'Пушкин': 'S', 'открыл': 'V', 'кричит': 'V', 'Смотри': 'V', 'Арина': 'S', 'Родионовна': 'S', 'я': 'S', 'при': 'PR', 'шел': 'V', 'Лермонтов': 'S', 'хотел': 'V', 'у': 'PR', 'Пушкина': 'S', 'жену': 'S', 'увести': 'V', 'На': 'PART', 'Кавказ': 'S', 'Все': 'A', 'смот': 'S', 'рел': 'S', 'нее': 'S', 'из-за': 'PR', 'колонн': 'S', 'смотрел': 'V', 'Вдруг': 'A', 'устыдился': 'V', 'своих': 'A', 'жела': 'S', 'ний': 'S', 'думает': 'V', 'зеркало': 'S', 'русской': 'A', 'революции': 'S', 'а': 'CONJ', 'свинья': 'S', 'Пошел': 'V', 'встал': 'V', 'перед': 'PR', 'ним': 'S', 'колени': 'S', 'где': 'A', 'твой': 'A', 'кинжал': 'S', 'Вот': 'PART', 'грудь': 'S', 'моя': 'A', 'смеялся': 'V', 'Однажды': 'A', 'стрелялся': 'V', 'Гоголем': 'S', 'Стреляй': 'V', 'первым': 'A', 'ты': 'S', 'Как': 'A', 'Нет': 'PART', 'Ах': 'INTJ', 'Так': 'A', 'стали': 'V', 'стреляться': 'V', 'Лев': 'S', 'Толстой': 'S', 'детей': 'S', 'по': 'PR', 'Тверскому': 'A', 'бульвару': 'S', 'увидел': 'V', 'впереди': 'PR', 'Конечно': 'A', 'это': 'S', 'уже': 'A', 'ребе': 'S', 'нок': 'S', 'подросток': 'S', 'подумал': 'V', 'все': 'S', 'равно': 'A', 'дай': 'V', 'догоню': 'V', 'поглажу': 'V', 'головке': 'S', 'побежал': 'V', 'догонять': 'V', 'же': 'PART', 'зная': 'V', 'толстовских': 'A', 'намерений': 'S', 'бросился': 'V', 'наутек': 'A', 'Пробе': 'S', 'гая': 'S', 'мимо': 'A', 'городового': 'S', 'сей': 'A', 'страж': 'S', 'порядка': 'S', 'был': 'V', 'возмущен': 'V', 'неприличной': 'A', 'быстротою': 'S', 'бега': 'S', 'людном': 'A', 'месте': 'S', 'бегом': 'A', 'устремился': 'V', 'вслед': 'A', 'целью': 'S', 'остановить': 'V', 'Западная': 'A', 'пресса': 'S', 'писала': 'V', 'что': 'CONJ', 'России': 'S', 'литера': 'S', 'торы': 'S', 'подвергаются': 'V', 'преследованиям': 'S', 'со': 'PR', 'стороны': 'S', 'властей': 'S', 'купил': 'V', 'яблок': 'S', 'стал': 'V', 'угощать': 'V', 'присутствующих': 'V', 'дам': 'V', 'брали': 'V', 'говорили': 'V', 'мерси': 'S', 'Когда': 'A', 'подошла': 'V', 'Наталья': 'S', 'Николаевна': 'S', 'сестрой': 'S', 'Александриной': 'S', 'от': 'PR', 'волненья': 'S', 'так': 'A', 'задрожал': 'V', 'яблоко': 'S', 'упало': 'V', 'ее': 'S', 'ногам': 'S', 'Натальи': 'S', 'Николаевны': 'S', 'Александрины': 'S', 'Одна': 'A', 'собак': 'S', 'схватила': 'V', 'бросилась': 'V', 'бежать': 'V', 'Александрина': 'S', 'конечно': 'A', 'побежала': 'V', 'за': 'PR', 'ней': 'S', 'Они': 'S', 'были': 'V', 'одни': 'A', 'впервые': 'A', 'жизни': 'S', 'Александ': 'S', 'рина': 'S', 'собачкой': 'S', 'Кстати': 'A', 'она': 'S', 'догнала': 'V', 'решил': 'V', 'испугать': 'V', 'Тургенева': 'S', 'спрятался': 'V', 'Тверском': 'A', 'бульваре': 'S', 'под': 'PR', 'лавкой': 'S', 'этот': 'A', 'день': 'S', 'другой': 'A', 'Тут': 'A', 'Тургенев': 'S', 'идет': 'V', 'они': 'S', 'оба': 'NUM', 'выскочат': 'V', 'играл': 'V', 'ними': 'S', 'весь': 'A', 'проголодался': 'V', 'Сонечка': 'S', 'ангелочек': 'S', 'сде': 'S', 'лай': 'S', 'мне': 'S', 'тюрьку': 'S', 'Она': 'S', 'возражает': 'V', 'Левушка': 'S', 'видишь': 'V', 'Вой': 'S', 'ну': 'PART', 'мир': 'S', 'переписываю': 'V', 'возопил': ' ...

# %%
from collections import Counter
absolut_counts = Counter(parts)
print(absolut_counts)
mnogo = len(parts)
for s in absolut_counts.items():
    print('{} : ipm = {}'.format(s[0], s[1] / mnogo * 1000000))
# Out:
# Counter({'S': 1135, 'V': 580, 'A': 448, 'CONJ': 260, 'PR': 253, 'PART': 157, 'NUM': 11, 'INTJ': 9})
# PR : ipm = 88678.58394672275
# S : ipm = 397826.84893094987
# V : ipm = 203294.77742726952
# A : ipm = 157027.69015071855
# CONJ : ipm = 91132.14160532772
# PART : ipm = 55029.7932001402
# INTJ : ipm = 3154.5741324921137
# NUM : ipm = 3855.59060637925
